# %% [markdown]
# Ref:
# https://vimsky.com/zh-tw/examples/usage/python-tf.keras.losses.SparseCategoricalCrossentropy-tf.html
#
# https://www.tensorflow.org/api_docs/python/tf/keras/losses

# %% [markdown]
# 1.BinaryCrossentropy
#
# https://vimsky.com/zh-tw/examples/usage/python-tf.keras.losses.BinaryCrossentropy-tf.html
#
# https://www.tensorflow.org/api_docs/python/tf/keras/losses/BinaryCrossentropy

# %% [markdown]
# 2.KLDivergence
#
# https://vimsky.com/zh-tw/examples/usage/python-tf.keras.losses.KLDivergence-tf.html
#
# https://www.tensorflow.org/api_docs/python/tf/keras/losses/KLDivergence

# %% [markdown]
# 3.MeanAbsoluteError
#
# https://vimsky.com/zh-tw/examples/usage/python-tf.keras.losses.MeanAbsoluteError-tf.html
#
# https://www.tensorflow.org/api_docs/python/tf/keras/losses/MeanAbsoluteError

# %% [markdown]
# 4.MeanSquaredError
#
# https://www.tensorflow.org/api_docs/python/tf/keras/losses/MeanSquaredError
#
# https://vimsky.com/zh-tw/examples/usage/python-tf.keras.losses.MeanSquaredError-tf.html
