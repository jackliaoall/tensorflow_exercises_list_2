# %% [markdown]
# Ref: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/Callback
#
# https://zhuanlan.zhihu.com/p/416956472
#
# https://keras.io/zh/callbacks/
