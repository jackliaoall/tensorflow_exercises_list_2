# %% [markdown]
# Ref: https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
#
# https://keras.io/zh/optimizers/
#
# https://ithelp.ithome.com.tw/m/articles/10270394
#
# https://www.youtube.com/watch?v=KAI1_bM7Vec
#
# https://medium.com/%E9%9B%9E%E9%9B%9E%E8%88%87%E5%85%94%E5%85%94%E7%9A%84%E5%B7%A5%E7%A8%8B%E4%B8%96%E7%95%8C/%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92ml-note-sgd-momentum-adagrad-adam-optimizer-f20568c968db
#
# https://ithelp.ithome.com.tw/articles/10236554
