# %% [markdown]
# Ref: https://keras.io/zh/backend/#_1
#
# https://runebook.dev/zh-CN/docs/tensorflow/keras/backend
#
# https://www.tensorflow.org/api_docs/python/tf/keras/backend

# %% [markdown]
# (1)epsilon:
#
# 浮點數，防止除0錯誤的小數字
#
# (2)image_data_format:
#
# https://blog.csdn.net/weixin_43450646/article/details/115068971
#
# (3)backend.rnn:
#
# tf.keras.layers.RNN, call的核心是呼叫keras後端方法keras.backend.rnn（K.rnn）
#
# https://tw.pythontechworld.com/article/detail/GR3xXsGOgzek
